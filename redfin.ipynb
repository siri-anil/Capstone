# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
homes_sold=pd.read_csv('data/homes_sold1.csv')
homes_sold
# Out:
#      Day of Year  Year of Period End Period Begin  Period End  \
# 0              1                2023    12/5/2022    1/1/2023
# 1              2                2022    12/6/2021    1/2/2022
# 2              3                2021    12/7/2020    1/3/2021
# 3              7                2024   12/11/2023    1/7/2024
# 4              8                2023   12/12/2022    1/8/2023
# ..           ...                 ...          ...         ...
# 165          353                2021   11/22/2021  12/19/2021
# 166          358                2023   11/27/2023  12/24/2023
# 167          359                2022   11/28/2022  12/25/2022
# 168          360                2021   11/29/2021  12/26/2021
# 169          365                2023    12/4/2023  12/31/2023
#
#     adjusted_average_homes_sold  adjusted_average_homes_sold_yoy  \
# 0                        58,989                        -0.330872
# 1                        88,158                         0.014722
# ...

# %%
sales=pd.read_csv('data/sales.csv')

# %%
sales
# Out:
#                         Region   Jan-12   Feb-12   Mar-12   Apr-12   May-12  \
# 0                     National  274,098  302,605  390,982  401,531  460,551
# 1       Chicago, IL metro area    3,989    4,316    5,739    6,049    7,280
# 2   Los Angeles, CA metro area    5,040    5,266    6,805    6,648    7,376
# 3       Seattle, WA metro area    1,909    2,285    2,961    3,149    3,566
# 4        Boston, MA metro area    2,116    2,168    2,894    3,271    4,274
# 5  Philadelphia, PA metro area      972      990    1,324    1,352    1,647
# 6    Washington, DC metro area    3,263    3,674    4,524    4,984    5,860
#
#     Jun-12   Jul-12   Aug-12   Sep-12  ...   May-23   Jun-23   Jul-23  \
# 0  484,379  447,674  481,854  389,466  ...  497,908  525,032  450,307
# 1    7,913    7,386    8,030    6,542  ...    7,838    8,700    7,186
# 2    7,618    7,151    7,916    6,339  ...    4,685    4,864    4,099
# 3    3,733    3,598    3,777    3,096  ...    3,215    3,380    2,985
# ...

# %%
sales.columns
# Out:
# Index(['Region', 'Jan-12', 'Feb-12', 'Mar-12', 'Apr-12', 'May-12', 'Jun-12',
#        'Jul-12', 'Aug-12', 'Sep-12',
#        ...
#        'May-23', 'Jun-23', 'Jul-23', 'Aug-23', 'Sep-23', 'Oct-23', 'Nov-23',
#        'Dec-23', 'Jan-24', 'Feb-24'],
#       dtype='object', length=147)

# %%
columns_to_drop=['Jan-12', 'Feb-12', 'Mar-12', 'Apr-12', 'May-12', 'Jun-12','Jul-12', 'Aug-12', 'Sep-12','Oct-12','Nov-12','Dec-12',
          'Jan-13', 'Feb-13', 'Mar-13', 'Apr-13', 'May-13', 'Jun-13','Jul-13', 'Aug-13', 'Sep-13','Oct-13','Nov-13','Dec-13','Jan-14', 'Feb-14', 'Mar-14', 'Apr-14', 'May-14', 'Jun-14',
       'Jul-14', 'Aug-14', 'Sep-14','Oct-14','Nov-14','Dec-14','Jan-15', 'Feb-15', 'Mar-15', 'Apr-15', 'May-15', 'Jun-15','Jul-15', 'Aug-15', 'Sep-15','Oct-15','Nov-15','Dec-15','Jan-16', 'Feb-16', 'Mar-16', 'Apr-16', 'May-16', 'Jun-16','Jul-16', 'Aug-16', 'Sep-16','Oct-16','Nov-16','Dec-16']

# %%
sales.drop(columns=columns_to_drop,inplace=True)

# %%
sales
# Out:
#                         Region   Jan-17   Feb-17   Mar-17   Apr-17   May-17  \
# 0                     National  356,977  364,271  527,485  510,573  622,768
# 1       Chicago, IL metro area    5,504    5,250    8,450    8,795   10,761
# 2   Los Angeles, CA metro area    4,815    4,537    6,614    5,951    7,106
# 3       Seattle, WA metro area    2,907    2,865    4,067    3,852    5,086
# 4        Boston, MA metro area    3,205    2,228    3,462    3,279    4,699
# 5  Philadelphia, PA metro area    1,503    1,513    2,074    2,089    2,577
# 6    Washington, DC metro area    4,129    4,373    6,152    6,417    7,906
#
#     Jun-17   Jul-17   Aug-17   Sep-17  ...   May-23   Jun-23   Jul-23  \
# 0  684,558  584,347  621,697  529,091  ...  497,908  525,032  450,307
# 1   12,068    9,720   10,125    8,274  ...    7,838    8,700    7,186
# 2    8,034    6,496    7,567    6,602  ...    4,685    4,864    4,099
# 3    5,576    4,977    5,434    4,764  ...    3,215    3,380    2,985
# ...

# %% [markdown]
# sales.drop(columns==['Jan-12', 'Feb-12', 'Mar-12', 'Apr-12', 'May-12', 'Jun-12','Jul-12', 'Aug-12', 'Sep-12','Oct-12','Nov-12','Dec-12',
#           'Jan-13', 'Feb-13', 'Mar-13', 'Apr-13', 'May-13', 'Jun-13','Jul-13', 'Aug-13', 'Sep-13','Oct-13','Nov-13','Dec-13','Jan-14', 'Feb-14', 'Mar-14', 'Apr-14', 'May-14', 'Jun-14',
#        'Jul-14', 'Aug-14', 'Sep-14','Oct-14','Nov-14','Dec-14','Jan-15', 'Feb-15', 'Mar-15', 'Apr-15', 'May-15', 'Jun-15','Jul-15', 'Aug-15', 'Sep-15','Oct-15','Nov-15','Dec-15','Jan-16', 'Feb-16', 'Mar-16', 'Apr-16', 'May-16', 'Jun-16','Jul-16', 'Aug-16', 'Sep-16','Oct-16','Nov-16','Dec-16',inplace=True])
