# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
pip install xlrd>=2.0.1
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel('data/HPI_PO_monthly_nsa.xls')
# Out:
#    Monthly Price Change Estimates for U.S. and Census Divisions Unnamed: 1  \
# 0   Purchase-Only FHFA HPI® (Not Seasonally Adjust...                  NaN
# 1                                                 NaN                 U.S.
# 2                   1-Month Change:\nDec  23 - Jan 24               -0.003
# 3                                    Nov  23 - Dec 23               -0.006
# 4                                 (Previous Estimate)               -0.006
# 5                                    Oct  23 - Nov 23               -0.002
# 6                                 (Previous Estimate)               -0.003
# 7                                    Sep  23 - Oct 23               -0.002
# 8                                 (Previous Estimate)               -0.002
# 9                                    Aug  23 - Sep 23                0.003
# 10                                (Previous Estimate)                0.003
# ...

# %%
hpi=pd.read_csv('data/HPI_master.csv')
hpi
# Out:
#              hpi_type     hpi_flavor  frequency                   level  \
# 0         traditional  purchase-only    monthly  USA or Census Division
# 1         traditional  purchase-only    monthly  USA or Census Division
# 2         traditional  purchase-only    monthly  USA or Census Division
# 3         traditional  purchase-only    monthly  USA or Census Division
# 4         traditional  purchase-only    monthly  USA or Census Division
# ...               ...            ...        ...                     ...
# 124809  developmental  purchase-only  quarterly             Puerto Rico
# 124810  developmental  purchase-only  quarterly             Puerto Rico
# 124811  developmental  purchase-only  quarterly             Puerto Rico
# 124812  developmental  purchase-only  quarterly             Puerto Rico
# 124813  developmental  purchase-only  quarterly             Puerto Rico
#
#                          place_name place_id    yr  period  index_nsa  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
#hpi_new=hpi.drop(hpi[hpi['yr']<2017].index,inplace=True)

# %%
hpi_monthly=hpi.loc[hpi['frequency']=='monthly'].reset_index(drop=True)
hpi_monthly
# Out:
#         hpi_type     hpi_flavor frequency                   level  \
# 0    traditional  purchase-only   monthly  USA or Census Division
# 1    traditional  purchase-only   monthly  USA or Census Division
# 2    traditional  purchase-only   monthly  USA or Census Division
# 3    traditional  purchase-only   monthly  USA or Census Division
# 4    traditional  purchase-only   monthly  USA or Census Division
# ..           ...            ...       ...                     ...
# 845  traditional  purchase-only   monthly  USA or Census Division
# 846  traditional  purchase-only   monthly  USA or Census Division
# 847  traditional  purchase-only   monthly  USA or Census Division
# 848  traditional  purchase-only   monthly  USA or Census Division
# 849  traditional  purchase-only   monthly  USA or Census Division
#
#                       place_name place_id    yr  period  index_nsa  index_sa
# 0    East North Central Division   DV_ENC  2017       1     191.82    195.12
# ...

# %%
hpi_quarterly=hpi.loc[hpi['frequency']=='quarterly'].reset_index(drop=True)
hpi_quarterly
# Out:
#             hpi_type        hpi_flavor  frequency        level   place_name  \
# 0        traditional  all-transactions  quarterly          MSA  Abilene, TX
# 1        traditional  all-transactions  quarterly          MSA  Abilene, TX
# 2        traditional  all-transactions  quarterly          MSA  Abilene, TX
# 3        traditional  all-transactions  quarterly          MSA  Abilene, TX
# 4        traditional  all-transactions  quarterly          MSA  Abilene, TX
# ...              ...               ...        ...          ...          ...
# 22335  developmental     purchase-only  quarterly  Puerto Rico  Puerto Rico
# 22336  developmental     purchase-only  quarterly  Puerto Rico  Puerto Rico
# 22337  developmental     purchase-only  quarterly  Puerto Rico  Puerto Rico
# 22338  developmental     purchase-only  quarterly  Puerto Rico  Puerto Rico
# 22339  developmental     purchase-only  quarterly  Puerto Rico  Puerto Rico
#
#       place_id    yr  period  index_nsa  index_sa
# ...

# %%
#hpi_quarterly['place_name'].str[-2: ]
# Out:
# 0        TX
# 1        TX
# 2        TX
# 3        TX
# 4        TX
#          ..
# 22335    co
# 22336    co
# 22337    co
# 22338    co
# 22339    co
# Name: place_name, Length: 22340, dtype: object

# %%
hpi_quarterly.place_name.value_counts()
# Out:
# place_name
# Tampa-St. Petersburg-Clearwater, FL                         112
# Massachusetts                                               112
# Maine                                                       112
# Phoenix-Mesa-Chandler, AZ                                   112
# Michigan                                                    112
# Minnesota                                                   112
# Missouri                                                    112
# Mississippi                                                 112
# Montana                                                     112
# North Carolina                                              112
# North Dakota                                                112
# Nebraska                                                    112
# New Hampshire                                               112
# Los Angeles-Long Beach-Glendale, CA (MSAD)                  112
# ...

# %% [markdown]
# Nashville-Davidson--Murfreesboro--Franklin, TN
# Tennessee
# Texas
# Atlanta-Sandy Springs-Alpharetta, GA
# Ohio

# %%
TN_hpi_quarterly=hpi_quarterly.loc[hpi_quarterly['place_name']=='Tennessee'].sort_values(by='yr').reset_index()
TN_hpi_quarterly
# Out:
#      index     hpi_type        hpi_flavor  frequency  level place_name  \
# 0    12484  traditional  all-transactions  quarterly  State  Tennessee
# 1    20102  traditional     purchase-only  quarterly  State  Tennessee
# 2    20103  traditional     purchase-only  quarterly  State  Tennessee
# 3    15595  traditional     expanded-data  quarterly  State  Tennessee
# 4    15594  traditional     expanded-data  quarterly  State  Tennessee
# 5    15593  traditional     expanded-data  quarterly  State  Tennessee
# 6    15592  traditional     expanded-data  quarterly  State  Tennessee
# 7    20101  traditional     purchase-only  quarterly  State  Tennessee
# 8    21696    non-metro  all-transactions  quarterly  State  Tennessee
# 9    21697    non-metro  all-transactions  quarterly  State  Tennessee
# 10   21698    non-metro  all-transactions  quarterly  State  Tennessee
# 11   21699    non-metro  all-transactions  quarterly  State  Tennessee
# ...

# %%
TN_hpi_quarterly.plot('yr', 'index_nsa', kind='bar');
# Out:
# <Axes: xlabel='yr'>

# %%
sns.lineplot(x=TN_hpi_quarterly['yr'],y=TN_hpi_quarterly['index_nsa']);
#t.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left', ncol=3);
